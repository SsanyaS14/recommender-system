# %% [markdown]
# # Wyoming Data Cleaning

# %% [markdown]
# ### This Data is used to find matrix factorization. Cleaning and getting rid of unnesscary values

# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv(r"C:\Users\super\Desktop\Syllabus\WD.csv")

# %%
# Turned the data in excel to csv file so must clean some of the title for organization
df.head()
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2   Unnamed: 3  \
# 0    API Number   Operator  Well Name  Well Number
# 1  490251039700   U.S. DOE      NPR-3      34-A-21
# 2  490250631800   U.S. DOE      NPR-3      82-S-14
# 3  490250632200   U.S. DOE      NPR-3     71-SX-14
# 4  490250632500   U.S. DOE      NPR-3      48-S-11
#
#   All Coordinates in Wyoming East Central State Plane, NAD 1927 Unnamed: 5  \
# 0                                           Northing               Easting
# 1                                           974652.3              794810.9
# 2                                             950092              808959.2
# 3                                           950778.6              808258.9
# 4                                           951369.6              806496.9
#
#     Unnamed: 6 Unnamed: 7   Unnamed: 8       Unnamed: 9  ...  Unnamed: 14  \
# 0  Well Status      Class  Total Depth  Datum Elevation  ...        Field
# ...

# %%
df = df.rename(columns=df.iloc[0])

# %%
# new data frame that will be used for wyoming data
df.drop([0])
# Out:
#         API Number  Operator Well Name     Well Number  Northing   Easting  \
# 1     490251039700  U.S. DOE     NPR-3         34-A-21  974652.3  794810.9
# 2     490250631800  U.S. DOE     NPR-3         82-S-14    950092  808959.2
# 3     490250632200  U.S. DOE     NPR-3        71-SX-14  950778.6  808258.9
# 4     490250632500  U.S. DOE     NPR-3         48-S-11  951369.6  806496.9
# 5     490250632600  U.S. DOE     NPR-3        88-St-11  951458.9  809057.2
# ...            ...       ...       ...             ...       ...       ...
# 1313  490252350700     RMOTC     RMOTC   45-3-X-21_PF1    974001  795501.4
# 1314  490252350800     RMOTC     RMOTC     45-4-TpX-21  973838.7  795478.7
# 1315  490254038000  U.S. DOE     NPR-3         26-AX-3  957491.1  799574.2
# 1316  490256012900  U.S. DOE     NPR-3  36-1-ShX-10(/)  952475.9  800507.2
# 1317  490256012901  U.S. DOE     NPR-3  36-2-ShX-10(/)  952475.9  800507.2
#
# ...

# %%
from math import sqrt
import matplotlib.pyplot as plt

# %%
df = df.dropna()

# %%
# drop NaN since provides no information
df.drop([0])
# Out:
#         API Number  Operator Well Name  Well Number  Northing   Easting  \
# 27    490250637500  U.S. DOE     NPR-3      61-S-11  956010.4  807675.4
# 31    490250638400  U.S. DOE     NPR-3      51-S-11  956063.9    806951
# 96    490250657800  U.S. DOE     NPR-3     78-SX-27  966839.8  802870.9
# 99    490250659800  U.S. DOE     NPR-3     62-AX-29  971059.7    791479
# 102   490250945000  U.S. DOE     NPR-3     41-AX-29  971357.1  790157.1
# ...            ...       ...       ...          ...       ...       ...
# 1195  490252265300  U.S. DOE     NPR-3     73-SX-33  964654.2  797666.9
# 1200  490252266400  U.S. DOE     NPR-3    17-StX-21  972423.3    793691
# 1202  490252267200  U.S. DOE     NPR-3   88-2-SX-33  961811.2  798080.7
# 1226  490252271100  U.S. DOE     NPR-3  16-1-ShX-11  952843.4  804211.7
# 1229  490252271500  U.S. DOE     NPR-3      52-X-23  944581.5  807247.3
#
#      Well Status Class Total Depth Datum Elevation  ...        Field  \
# ...
